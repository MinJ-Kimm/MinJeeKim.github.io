# %% [markdown]
# # 서울 대피소 현황 지도 만들기                    / Creating a Map of the Seoul Shelter

# %%
import pandas as pd
import folium

# %%
file = '/Users/margokim/Documents/Learning Spoons Data 2/파이썬 기초/Ch3)Data_Visualization/data/서울시 대피소 방재시설 현황 (좌표계_ WGS1984).csv'

raw = pd.read_csv(file, encoding = 'cp949') #utf - 8

# %%
raw.head(10)
# Out:
#    고유번호     대피소명칭                소재지  최대수용인원  현재수용인원 현재운영여부           전화번호  \
# 0     2    혜화초등학교  혜화동 13-1 (혜화로 32)     450       0      N       763-0606
# 1     3      새샘교회           홍제동 20-4     100       0      N       720-7040
# 2     4    한강중앙교회     포은로2가길 66(합정동)     130       0      N       337-6629
# 3     5  서울성산초등학교      양화로3길 94(합정동)     200       0      N       324-1407
# 4     6   상도1동경로당        상도동 159-282      20       0      N  010-8011-7330
# 5     7    상도초등학교          상도동 238-2    1300       0      N       822-0078
# 6     8      본동초교           노량진동 133     739       0      N       813-0408
# 7    10    남정초등학교          원효2가 54-1     300       0      N       712-8015
# 8    11    응암초등학교          응암3동 7-40    1484       0      N       303-3044
# 9    12    제일감리교회           흑석동 80-3     100       0      N    02-817-2541
#
#       행정동코드  행정동명칭 대피단계 비고          경도         위도
# 0  11110650    혜화동          126.999891  37.589128
# 1  11410655   홍제2동          126.950484  37.583660
# 2  11440680    합정동          126.910028  37.549343
# 3  11440680    합정동          126.910666  37.553495
# 4  11590530   상도1동          126.948269  37.500395
# 5  11590560   상도4동          126.937432  37.499735
# 6  11590510  노량진1동          126.953640  37.510054
# 7  11170560  원효로1동          126.965020  37.536534
# 8  11380600   응암3동          126.921779  37.588435
# 9  11590605    흑석동          126.962514  37.503025

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고유번호    694 non-null    int64
#  1   대피소명칭   694 non-null    object
#  2   소재지     694 non-null    object
#  3   최대수용인원  694 non-null    int64
#  4   현재수용인원  694 non-null    int64
#  5   현재운영여부  694 non-null    object
#  6   전화번호    694 non-null    object
#  7   행정동코드   694 non-null    int64
#  8   행정동명칭   694 non-null    object
#  9   대피단계    694 non-null    object
#  10  비고      694 non-null    object
#  11  경도      694 non-null    float64
#  12  위도      694 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 70.6+ KB

# %%
for i in range(len(raw)):

    lat = raw.loc[i , "위도"  ]
    long = raw.loc[i , "경도"]
    name = raw.loc[i, "대피소명칭"]

# %%
m = folium.Map(location = [37.5536067, 126.9674308], zoom_start = 12)

for i in range(len(raw)):

    lat = raw.loc[i , "위도"  ]
    long = raw.loc[i , "경도"]
    name = raw.loc[i, "대피소명칭"]

    folium.Marker([lat,long], tooltip = name).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b9b16a93a2347390ab291aa4436b993 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b9b16a93a2347390ab291aa4436b993&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4b9b16a93a2347390ab291aa4436b993 = L.map(
#                 &quot;map_4b9b16a93a2347390ab291aa4436b993&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_340b8d65cc21ccfce8ed5ee7b863fc72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             var marker_01ee71e0231ec711c7e89d4856349cd2 = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_01ee71e0231ec711c7e89d4856349cd2.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8e5a8dff5f7ccd1e2c5ab390c78b095f = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_8e5a8dff5f7ccd1e2c5ab390c78b095f.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0acc76c6dcece1cf629822dc3a6c794d = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_0acc76c6dcece1cf629822dc3a6c794d.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4a1e2a50efb02fc96221b4e7002fa3a2 = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_4a1e2a50efb02fc96221b4e7002fa3a2.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e7f2f2b70265315524fa93c5baa92d5 = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_5e7f2f2b70265315524fa93c5baa92d5.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be67d8477f7d0d36d9708413ee1fe70a = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_be67d8477f7d0d36d9708413ee1fe70a.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ae04072d3e6a0cfb5ffdc6c9a1213841 = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_ae04072d3e6a0cfb5ffdc6c9a1213841.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1ee1209f035050bfd8d5f7a2a06bea80 = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_1ee1209f035050bfd8d5f7a2a06bea80.bindTooltip(
#                 `&lt;div&gt;
#                      남정초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cdaa8bc6bce6d41cc2b57c1a77b8b610 = L.marker(
#                 [37.5884354, 126.9217785],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_cdaa8bc6bce6d41cc2b57c1a77b8b610.bindTooltip(
#                 `&lt;div&gt;
#                      응암초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f326b7e18316a9d82ad906da657f50a = L.marker(
#                 [37.5030252, 126.9625144],
#                 {}
#             ).addTo(map_4b9b16a93a2347390ab291aa4436b993);
#
#
#             marker_2f326b7e18316a9d82ad906da657f50a.bindTooltip(
#                 `&lt;div&gt;
#                      제일감리교회
#                  &lt;/div&gt;`,

# %%
m.save('/Users/margokim/Documents/Learning Spoons Data 2/파이썬 기초/Ch3)Data_Visualization/data/shelterM.html')

# %%
from folium.plugins import MarkerCluster

# %%
m = folium.Map(location = [37.5536067, 126.9674308], zoom_start = 12)

marker_cluster = MarkerCluster().add_to(m)

for i in range(len(raw)):

    lat = raw.loc[i , "위도"  ]
    long = raw.loc[i , "경도"]
    name = raw.loc[i, "대피소명칭"]

    folium.Marker([lat,long], tooltip = name).add_to(marker_cluster)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e036618409299948edfe9596fd91aa92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e036618409299948edfe9596fd91aa92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e036618409299948edfe9596fd91aa92 = L.map(
#                 &quot;map_e036618409299948edfe9596fd91aa92&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f87e420897377fcb74df706fae968975 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e036618409299948edfe9596fd91aa92);
#
#
#             var marker_cluster_d4b69fad87e5ccc3cc38e14f67784394 = L.markerClusterGroup(
#                 {}
#             );
#             map_e036618409299948edfe9596fd91aa92.addLayer(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             var marker_91650efb178f2612185e19c5299def6b = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_91650efb178f2612185e19c5299def6b.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_685ff9259a08d2615457151c492b52ce = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_685ff9259a08d2615457151c492b52ce.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5378f8763b70312fdfa8eec22daeed63 = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_5378f8763b70312fdfa8eec22daeed63.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0d9cd23ce128a49ab1023b97cacc87d = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_a0d9cd23ce128a49ab1023b97cacc87d.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f36505ab697049595e7b011d0311f69f = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_f36505ab697049595e7b011d0311f69f.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8c34712703c734b1eb53a9a0135082ae = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_8c34712703c734b1eb53a9a0135082ae.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d8831913f8f1188aef52039425d8249 = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_2d8831913f8f1188aef52039425d8249.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af51165defbca862f774a8f9500c5fd9 = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(marker_cluster_d4b69fad87e5ccc3cc38e14f67784394);
#
#
#             marker_af51165defbca862f774a8f9500c5fd9.bindTooltip(
#                 `&lt;div&gt;
#                      남정초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %%
from folium.plugins import MiniMap

# %%
m = folium.Map(location = [37.5536067, 126.9674308], zoom_start = 12)

marker_cluster = MarkerCluster().add_to(m)
minimap = MiniMap()

minimap.add_to(m)

for i in range(len(raw)):

    lat = raw.loc[i , "위도"  ]
    long = raw.loc[i , "경도"]
    name = raw.loc[i, "대피소명칭"]

    folium.Marker([lat,long], tooltip = name).add_to(marker_cluster)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_865ee9868b18624a8cf11d5f9a4028c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_865ee9868b18624a8cf11d5f9a4028c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_865ee9868b18624a8cf11d5f9a4028c4 = L.map(
#                 &quot;map_865ee9868b18624a8cf11d5f9a4028c4&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c026f76f72390786951cd890cfa52a08 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_865ee9868b18624a8cf11d5f9a4028c4);
#
#
#             var marker_cluster_ff3841dea70548b8406370b2235f9bb7 = L.markerClusterGroup(
#                 {}
#             );
#             map_865ee9868b18624a8cf11d5f9a4028c4.addLayer(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             var marker_777c44161de500d159ff8506c84ec658 = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_777c44161de500d159ff8506c84ec658.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b740cfe8e2d9b67126d16463d7d014a = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_5b740cfe8e2d9b67126d16463d7d014a.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e2194dff419f89e0adbe59ef4a4d61da = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_e2194dff419f89e0adbe59ef4a4d61da.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bfd40641a1b1ba6f1f3cfbc9247a5d5e = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_bfd40641a1b1ba6f1f3cfbc9247a5d5e.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6510857128bd10e886db4b5c43fe5112 = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_6510857128bd10e886db4b5c43fe5112.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d865132c698d224755424fc5127659d = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_4d865132c698d224755424fc5127659d.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6579fac13dabc783d875b752b823f79a = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548b8406370b2235f9bb7);
#
#
#             marker_6579fac13dabc783d875b752b823f79a.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_317fe3104760e9f669748f4f57eb3a0c = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(marker_cluster_ff3841dea70548

# %%
m.save('/Users/margokim/Documents/Learning Spoons Data 2/파이썬 기초/Ch3)Data_Visualization/data/shelterM.html')
