# %% [markdown]
# # Introduction
# On 8 May 2013, Alex Ferguson, Manchester United manager and European football coach, retired. Manchester United retired Alex Ferguson and appointed David Moise, then head coach of other teams, but ended the season in a false decline. Since then, world-class directors such as Louis van Hal and Jose Mourinho have taken the helm of Manchester United after David Moise left, but Manchester United has not regained its status when Alex Ferguson was in charge. After these incidents, Manchester United made a special move to appoint then-manager Ole Gunnar Solskjaer, who was coached by Alex Ferguson, and as of March 2020, Ole Gunnar Solskjaer succeeded in reversing Manchester United's mood by recruiting only two players in the winter market for the 2019-2020 season.
#
#
# ## Project Research Question
# Who are the only two players who have reversed the mood of Manchester United, and did Manchester United succeed in reversing the game because of those two players?
#
# Before the problem is solved, analyze the Manchester United team through 2018/2019 FIFA data, find the type of foreign European soccer players needed for Manchester United, and compare them with those currently recruited by Ole Gunnar Solskjaer.

# %% [markdown]
# # 1. Data collection

# %% [markdown]
# ### a. 데이터 불러오기

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/margokim/Documents/Learning Spoons Data 2/파이썬 포트폴리오/포트폴리오 1. FIFA 실습/data/FIFA_data.csv')

# %%
data.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina     94.0       94.0
# 1   20801  Cristiano Ronaldo   33    Portugal     94.0       94.0
# 2  190871          Neymar Jr   26      Brazil     92.0       93.0
# 3  193080             De Gea   27       Spain     91.0       93.0
# 4  192985       K. De Bruyne   27     Belgium     91.0       92.0
#
#                   Club    Value   Wage Preferred Foot  \
# 0         FC Barcelona  €110.5M  €565K           Left
# 1             Juventus     €77M  €405K          Right
# 2  Paris Saint-Germain  €118.5M  €290K          Right
# 3    Manchester United     €72M  €260K          Right
# 4      Manchester City    €102M  €355K          Right
#
#    International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 0                       5.0        4.0          4.0       RF           10.0
# 1                       5.0        4.0          5.0       ST            7.0
# ...

# %%
pd.set_option('display.max_columns', 80)

# %%
data.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina     94.0       94.0
# 1   20801  Cristiano Ronaldo   33    Portugal     94.0       94.0
# 2  190871          Neymar Jr   26      Brazil     92.0       93.0
# 3  193080             De Gea   27       Spain     91.0       93.0
# 4  192985       K. De Bruyne   27     Belgium     91.0       92.0
#
#                   Club    Value   Wage Preferred Foot  \
# 0         FC Barcelona  €110.5M  €565K           Left
# 1             Juventus     €77M  €405K          Right
# 2  Paris Saint-Germain  €118.5M  €290K          Right
# 3    Manchester United     €72M  €260K          Right
# 4      Manchester City    €102M  €355K          Right
#
#    International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 0                       5.0        4.0          4.0       RF           10.0
# 1                       5.0        4.0          5.0       ST            7.0
# ...

# %% [markdown]
# ### b. After verifying the data, establishing an analysis plan

# %% [markdown]
# | 컬럼 명 |  컬럼 의미 |
# |--------|-----------|
# | ID | 고유의 번호 |
# | Name | 이름 |
# | Age | 나이 |
# | Overall | 현재 능력치 |
# | Potential | 잠재 능력치 |
# | Club | 소속 팀 |
# | Value | 예상 이적료 (유로) |
# | Wage | 주급 (유로)|
# | Preferred Foot | 잘 사용하는 발 |
# | Weak Foot | 잘 사용하지 않는 발 |
# | Skill Moves | 개인기 |
# | Position | 포지션 |
# | Jersey Number | 등번호 |
# | Joined | 소속 팀 입단 날짜 |
# | Contract Valid Until | 계약 기간 |
# | Height | 키 (피트) |
# | Weight | 몸무게 (파운드) |
# | LS ~ RB | 포지션 별 능력치 |
# | Crossing ~ GKReflexes | 세부 능력치 |
# | Release Clause | 바이아웃 |

# %% [markdown]
# ###  how to analyze the subject using the columns
#
# Analysis Order
# 1. Analysis of Manchester United players
# 2. Compare abilities with Manchester United's regional rival Manchester City player
# 3. Select 2 positions that are lacking
# 3. Recruit 2 players from other teams considering Manchester United's financial, feasibility, and recruitment policy

# %% [markdown]
# ## 2. Manchester United Analysis - What players do Manchester United have?

# %% [markdown]
# ### a. EDA

# %%
mu = data[data ['Club'] == 'Manchester United']

# %%
mu['Club'].unique()
# Out:
# array(['Manchester United'], dtype=object)

# %%
data ['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto',
#        'FC Schalke 04', 'Beşiktaş JK', 'LA Galaxy', 'Sporting CP',
#        'Real Betis', 'Olympique de Marseille', 'RC Celta',
#        'Bayer 04 Leverkusen', 'Real Sociedad', 'Villarreal CF',
#        'Sevilla FC', 'SL Benfica', 'AS Saint-Étienne', 'AS Monaco',
#        'Leicester City', 'Atalanta', 'Grêmio', 'Atlético Mineiro',
#        'RB Leipzig', 'Ajax', 'Dalian YiFang FC', 'Everton',
#        'West Ham United', '1. FC Köln', 'TSG 1899 Hoffenheim',
#        'Shanghai SIPG FC', 'OGC Nice', 'Al Nassr',
#        'Wolverhampton Wanderers', 'Borussia Mönchengladbach',
# ...

# %%
mu.shape
# Out:
# (33, 80)

# %%
print(f"인원 : {mu.shape[0]}") 
print(f"맨유 선수들의 포지션 : {mu['Position'].unique()}")
print(f"평균 능력치 : {mu['Overall'].mean()}")
print(f"평균 잠재 능력치 : {mu['Potential'].mean()}")
# Out:
# 인원 : 33
# 맨유 선수들의 포지션 : ['GK' 'RDM' 'ST' 'RW' 'LW' 'CDM' 'RM' 'CM' 'CAM' 'CB' 'RCB' 'LB' 'RB']
# 평균 능력치 : 80.18181818181819
# 평균 잠재 능력치 : 82.81818181818181

# %%
import seaborn as sns
sns.countplot(mu['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(mu['Position'])
# Out:
# <AxesSubplot:xlabel='Position', ylabel='count'>

# %%
sns.boxplot(data = mu, x = 'Position', y='Overall')
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Overall'>

# %% [markdown]
# ### Handling Outliers

# %%
mu[mu['Overall'] > 100]
# Out:
#            ID         Name  Age Nationality  Overall  Potential  \
# 11422  237160  R. Williams   19     England    150.0       79.0
#
#                     Club  Value Wage Preferred Foot  International Reputation  \
# 11422  Manchester United  €875K  €8K          Right                       1.0
#
#        Weak Foot  Skill Moves Position  Jersey Number       Joined  \
# 11422        3.0          2.0       CB           52.0  Jan 1, 2016
#
#       Contract Valid Until Height  Weight    LS    ST    RS    LW    LF    CF  \
# 11422                 2019    6'0  165lbs  46+2  46+2  46+2  47+2  46+2  46+2
#
#          RF    RW   LAM   CAM   RAM    LM   LCM    CM   RCM    RM   LWB   LDM  \
# 11422  46+2  47+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2  55+2  57+2
#
#         CDM   RDM   RWB    LB   LCB    CB   RCB    RB  Crossing  Finishing  \
# 11422  57+2  57+2  55+2  57+2  62+2  62+2  62+2  57+2      32.0       27.0
#
# ...

# %%
mu[mu['Position'] == 'CB'][['Position', 'Overall', 'CB']]
# Out:
#       Position  Overall    CB
# 327         CB     81.0  80+2
# 584         CB     79.0  77+2
# 629         CB     79.0  78+3
# 654         CB     79.0  78+2
# 11081       CB     75.0  62+2
# 11422       CB    150.0  62+2

# %%
mu['Overall'][11422] = 75

# %%
sns.boxplot(data = mu, x = 'Position', y='Overall')
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Overall'>

# %%
#다른 능력치도 outlier 확인

sns.boxplot(data = mu, x = 'Position', y='Potential')
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Potential'>

# %% [markdown]
# ### Find Missing Values

# %%
mu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 3 to 12545
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        33 non-null     int64
#  1   Name                      33 non-null     object
#  2   Age                       33 non-null     int64
#  3   Nationality               33 non-null     object
#  4   Overall                   33 non-null     float64
#  5   Potential                 33 non-null     float64
#  6   Club                      33 non-null     object
#  7   Value                     33 non-null     object
#  8   Wage                      33 non-null     object
#  9   Preferred Foot            33 non-null     object
#  10  International Reputation  33 non-null     float64
#  11  Weak Foot                 33 non-null     float64
#  12  Skill Moves               33 non-null     float64
# ...

# %%
mu[mu.isnull()['LS']]

#골키퍼 포지션의 경우, 해당 값들이 null 값, NaN을 측정 할 수 없게 -1 로 교체
# Out:
#           ID       Name  Age Nationality  Overall  Potential  \
# 3     193080     De Gea   27       Spain     91.0       93.0
# 526   173373  S. Romero   31   Argentina     80.0       80.0
# 2561   53739   L. Grant   35     England     74.0       74.0
#
#                    Club  Value   Wage Preferred Foot  \
# 3     Manchester United   €72M  €260K          Right
# 526   Manchester United    €9M   €91K          Right
# 2561  Manchester United  €1.3M   €39K          Right
#
#       International Reputation  Weak Foot  Skill Moves Position  \
# 3                          4.0        3.0          1.0       GK
# 526                        3.0        3.0          1.0       GK
# 2561                       1.0        4.0          1.0       GK
#
#       Jersey Number        Joined Contract Valid Until Height  Weight   LS  \
# 3               1.0   Jul 1, 2011                 2020    6'4  168lbs  NaN
# 526             1.0  Jul 27, 2015                 2021    6'4  192lbs  NaN
# ...

# %%
mu = mu.fillna(-1)

# %%
mu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 3 to 12545
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        33 non-null     int64
#  1   Name                      33 non-null     object
#  2   Age                       33 non-null     int64
#  3   Nationality               33 non-null     object
#  4   Overall                   33 non-null     float64
#  5   Potential                 33 non-null     float64
#  6   Club                      33 non-null     object
#  7   Value                     33 non-null     object
#  8   Wage                      33 non-null     object
#  9   Preferred Foot            33 non-null     object
#  10  International Reputation  33 non-null     float64
#  11  Weak Foot                 33 non-null     float64
#  12  Skill Moves               33 non-null     float64
# ...

# %% [markdown]
# # 3. What position should Manchester United reinforce?

# %% [markdown]
# ### a. Data Treatment

# %% [markdown]
# Processing outliers and missing values and proceeding with the preprocessing necessary to compare capabilities with Manchester City players, the local rival of Manchester United

# %%
df = data[(data['Club'] == 'Manchester United') | (data['Club']=='Manchester City')]

df['Club'].unique()
# Out:
# array(['Manchester United', 'Manchester City'], dtype=object)

# %%
df['Value'].head()
# Out:
# 3       €72M
# 4      €102M
# 13      €60M
# 23    €64.5M
# 45      €64M
# Name: Value, dtype: object

# %%
import warnings

warnings.filterwarnings(action = 'ignore')

# %%
df['Value'] = df['Value'].str.replace('M', '000000')
df['Value'] = df['Value'].str.replace('K' , '000')

df['Value'] = df['Value'].str.slice(1,)

# %%
df['Value'] = df['Value'].str.replace('.','')
df['Value'] = df['Value'].astype(int)

df.head()
# Out:
#         ID          Name  Age Nationality  Overall  Potential  \
# 3   193080        De Gea   27       Spain     91.0       93.0
# 4   192985  K. De Bruyne   27     Belgium     91.0       92.0
# 13  168542   David Silva   32       Spain     90.0       90.0
# 23  153079     S. Agüero   30   Argentina     89.0       89.0
# 45  195864      P. Pogba   25      France     87.0       91.0
#
#                  Club      Value   Wage Preferred Foot  \
# 3   Manchester United   72000000  €260K          Right
# 4     Manchester City  102000000  €355K          Right
# 13    Manchester City   60000000  €285K           Left
# 23    Manchester City  645000000  €300K          Right
# 45  Manchester United   64000000  €210K          Right
#
#     International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 3                        4.0        3.0          1.0       GK            1.0
# 4                        4.0        5.0          4.0      RCM            7.0
# ...

# %%
mu = df[df['Club'] == 'Manchester United']
mc = df[df['Club'] == 'Manchester City']

# %%
mu.head()
# Out:
#          ID        Name  Age Nationality  Overall  Potential  \
# 3    193080      De Gea   27       Spain     91.0       93.0
# 45   195864    P. Pogba   25      France     87.0       91.0
# 47   192505   R. Lukaku   25     Belgium     87.0       89.0
# 93   184941  A. Sánchez   29       Chile     85.0       85.0
# 116  211300  A. Martial   22      France     84.0       90.0
#
#                   Club      Value   Wage Preferred Foot  \
# 3    Manchester United   72000000  €260K          Right
# 45   Manchester United   64000000  €210K          Right
# 47   Manchester United  625000000  €230K           Left
# 93   Manchester United  375000000  €215K          Right
# 116  Manchester United  425000000  €165K          Right
#
#      International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 3                         4.0        3.0          1.0       GK            1.0
# 45                        4.0        4.0          5.0      RDM            6.0
# ...

# %% [markdown]
# ### To compare the main players, M.United and M.City key players are selected
#
# -- GK: 1 person, CB: 4 people MF: 4 people ST: 2 people selected
# 1. The criteria for selection are the current capabilities
# - GK List = GK
# - CB List = CB, LCB, RCB, RB, LB
# - MF list = RCM, LCM, RDM, CDM, CM, RM, CAM
# - ST List = ST, LW, RW

# %%
#각 포지션별 리스트 작성

gk_list = ['GK']
cb_list = ['CB', 'LCB', 'RCB', 'RB', 'LB']
mf_list = ['RCM', 'LCM', 'RDM', 'CDM', 'CM', 'RM','CAM']
st_list = ['ST', 'LW', 'RW']

# %%
st_count = 2
mf_count = 4
cb_count = 4
gk_count = 1 

mu_id = []
mc_id = []

for index in mu.index:
    
    if mu['Position'][index] in gk_list :
        if gk_count != 0:
            mu_id.append(mu['ID'][index])
            gk_count -= 1
    elif mu['Position'][index] in cb_list :
        if cb_count != 0:
            mu['Position'][index] = 'CB'
            mu_id.append(mu['ID'][index])
            cb_count -= 1
    elif mu['Position'][index] in mf_list :
        if mf_count != 0:
            mu['Position'][index] = 'MF'
            mu_id.append(mu['ID'][index])
            mf_count -= 1
            
    else :
        if st_count != 0:
            mu['Position'][index] = 'ST'
            mu_id.append(mu['ID'][index])
            st_count -= 1

# %%
mu = mu[mu['ID'].isin(mu_id)]

mu.head()
# Out:
#          ID        Name  Age Nationality  Overall  Potential  \
# 3    193080      De Gea   27       Spain     91.0       93.0
# 45   195864    P. Pogba   25      France     87.0       91.0
# 47   192505   R. Lukaku   25     Belgium     87.0       89.0
# 93   184941  A. Sánchez   29       Chile     85.0       85.0
# 132  191202    N. Matić   29      Serbia     84.0       84.0
#
#                   Club      Value   Wage Preferred Foot  \
# 3    Manchester United   72000000  €260K          Right
# 45   Manchester United   64000000  €210K          Right
# 47   Manchester United  625000000  €230K           Left
# 93   Manchester United  375000000  €215K          Right
# 132  Manchester United   24000000  €165K           Left
#
#      International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 3                         4.0        3.0          1.0       GK            1.0
# 45                        4.0        4.0          5.0       MF            6.0
# ...

# %%
st_count = 2
mf_count = 4
cb_count = 4
gk_count = 1 


for index in mc.index:
    
    if mc['Position'][index] in gk_list :
        if gk_count != 0:
            mc_id.append(mc['ID'][index])
            gk_count -= 1
    elif mc['Position'][index] in cb_list :
        if cb_count != 0:
            mc['Position'][index] = 'CB'
            mc_id.append(mc['ID'][index])
            cb_count -= 1
    elif mc['Position'][index] in mf_list :
        if mf_count != 0:
            mc['Position'][index] = 'MF'
            mc_id.append(mc['ID'][index])
            mf_count -= 1
            
    else :
        if st_count != 0:
            mc['Position'][index] = 'ST'
            mc_id.append(mc['ID'][index])
            st_count -= 1

mc = mc[mc['ID'].isin(mc_id)]

# %%
df = pd.concat([mu, mc])

df
# Out:
#          ID          Name  Age  Nationality  Overall  Potential  \
# 3    193080        De Gea   27        Spain     91.0       93.0
# 45   195864      P. Pogba   25       France     87.0       91.0
# 47   192505     R. Lukaku   25      Belgium     87.0       89.0
# 93   184941    A. Sánchez   29        Chile     85.0       85.0
# 132  191202      N. Matić   29       Serbia     84.0       84.0
# 211  178088     Juan Mata   30        Spain     83.0       83.0
# 250  209297          Fred   25       Brazil     82.0       84.0
# 327  225508     E. Bailly   24  Ivory Coast     81.0       87.0
# 377  189881   C. Smalling   28      England     81.0       82.0
# 454  205988       L. Shaw   22      England     80.0       85.0
# 584  221660   V. Lindelöf   23       Sweden     79.0       85.0
# 4    192985  K. De Bruyne   27      Belgium     91.0       92.0
# 13   168542   David Silva   32        Spain     90.0       90.0
# 23   153079     S. Agüero   30    Argentina     89.0       89.0
# ...

# %% [markdown]
# ###  b.EDA
#  - Main players comparison

# %%
sns.boxplot(data = df, x='Position' , y = 'Overall', hue ='Club')
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Overall'>

# %%
sns.boxplot(data = df, x ='Position' , y ='Value', hue = 'Club')
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Value'>

# %% [markdown]
# Comparing MU players and MC players, it can be seen that MF and CB are positions with poor performance compared to transfer fees.

# %% [markdown]
# ## 4. Which player should Manchester United recruit?
# ## a. EDA
# - Identify which competitors should be replaced in the required positioned
# - The criteria are recruitment date, ability, potential, age
#
# ### Making a formula
# - Remaining Point = (Overall * 2 + Potential) / Age

# %%
mu['Point'] = (mu['Overall'] * 2 + mu['Potential']) / mu['Age']

# %%
mu[mu['Position'] == 'MF'][['Name', 'Overall', 'Potential', 'Age', 'Joined', 'Point']]
# Out:
#           Name  Overall  Potential  Age        Joined      Point
# 45    P. Pogba     87.0       91.0   25   Aug 9, 2016  10.600000
# 132   N. Matić     84.0       84.0   29  Jul 31, 2017   8.689655
# 211  Juan Mata     83.0       83.0   30  Jan 25, 2014   8.300000
# 250       Fred     82.0       84.0   25  Jun 21, 2018   9.920000

# %%
mu[mu['Position'] == 'CB'][['Name', 'Overall', 'Potential', 'Age', 'Joined', 'Point']]
# Out:
#             Name  Overall  Potential  Age        Joined      Point
# 327    E. Bailly     81.0       87.0   24   Jul 1, 2016  10.375000
# 377  C. Smalling     81.0       82.0   28   Jul 1, 2010   8.714286
# 454      L. Shaw     80.0       85.0   22  Jun 27, 2014  11.136364
# 584  V. Lindelöf     79.0       85.0   23   Jul 1, 2017  10.565217

# %% [markdown]
# Juan Mata, who has the lowest remaining points, recruited MF and CB one by one after C. Smalling was released

# %% [markdown]
# ### b. 시각화
#
# #### Manchester United's recruitment policy follows the recent recruitment of Solskjaer.
# - The younger a player is, the better
# - A player who is currently available as a starting pitcher rather than a potential player
# - Positions follow detailed positions of Mata and Smalling, RM and CB.

# %%
# Remove players except RM and CB positions

market = data[(data['Position'] == 'RM')| (data['Position'] == 'CB')]

market.head()
# Out:
#         ID        Name  Age Nationality  Overall  Potential  \
# 12  182493    D. Godín   32     Uruguay     90.0       90.0
# 25  231747   K. Mbappé   19      France     88.0       95.0
# 26  209331    M. Salah   26       Egypt     88.0       89.0
# 42  205600   S. Umtiti   24      France     87.0       92.0
# 73  177509  M. Benatia   31     Morocco     86.0       86.0
#
#                    Club   Value   Wage Preferred Foot  \
# 12      Atlético Madrid    €44M  €125K          Right
# 25  Paris Saint-Germain    €81M  €100K          Right
# 26            Liverpool  €69.5M  €255K           Left
# 42         FC Barcelona    €57M  €205K           Left
# 73             Juventus    €30M  €160K          Right
#
#     International Reputation  Weak Foot  Skill Moves Position  Jersey Number  \
# 12                       3.0        3.0          2.0       CB           10.0
# 25                       3.0        4.0          5.0       RM           10.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(2, 4, figsize = (20,10))

# %%
f, ax = plt.subplots(2, 4, figsize = (20,10))

vs_list = ['Age', 'Overall', 'Potential', 'Weak Foot']

for i in range (8):
    if i < 4 :
        colors = ['firebrick' if x > market[market['Position']=='CB'][:13][vs_list[i]].mean() else 'gray' for x in market[market['Position']=='CB'][:13][vs_list[i]]]
        sns.barplot(x = vs_list[i], y = 'Name', data = market [market['Position'] == 'CB'][:13], ax = ax[i//4, i%4], palette =colors)
        ax[i//4, i%4].axvline(market[market['Position']=='CB'][:13][vs_list[i]].mean(), ls = '--')
        
    else :
        sns.barplot(x = vs_list[i%4], y = 'Name', data = market[market['Position'] == 'RM'][:13], ax = ax[i//4, i%4], palette =colors)
        ax[i//4, i%4].axvline(market[market['Position']=='RM'][:13][vs_list[i%4]].mean(), ls = '--')

# %% [markdown]
# ## Final Conclusion.
#
# When comparing players to the market for the position to recruit RM and CB, the detailed positions of Mata and Smalling, <br>
# The CB position requires a young S.umtiti player among the players with high potential
# RM Possi will recruit F.Bernardeschi, the younger player among the high-potential players.
